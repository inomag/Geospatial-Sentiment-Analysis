# %% [markdown]
# ## WORD CLOUD

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-1.4.1-cp310-cp310-win_amd64.whl (10.6 MB)
#      --------------------------------------- 10.6/10.6 MB 21.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\bhargab nath\appdata\roaming\python\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\bhargab nath\appdata\roaming\python\python310\site-packages (from pandas) (1.22.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2021.3-py2.py3-none-any.whl (503 kB)
#      ------------------------------------- 503.5/503.5 KB 32.9 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\bhargab nath\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.4.1 pytz-2021.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df = pd.read_csv(r'./final datasets/Guwahati_Data.csv', encoding ="latin-1")
full_text = df.to_string()
print(len(full_text))
# Out:
# 5504094

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
comment_words = ''
stopwords = set(STOPWORDS)

for val in df['Full Text']:
    val = str(val)
    val = val.replace("posted", "")
    tokens = val.split()
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
    comment_words += " ".join(tokens)+" "

# %%
# comment_words = ' '.join(dict.fromkeys(comment_words.split()))

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
