# %% [markdown]
# ## WORD CLOUD BASED ON SILCHAR DATASETS

# %%
import pandas as pd
df = pd.read_csv(r'../final datasets/Silchar_Data.csv', encoding ="latin-1")

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
full_text = ''
stopwords = set(STOPWORDS)

for val in df['Full Text']:
    val = str(val)
    val = val.replace("posted", "")
    tokens = val.split()
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
    full_text += " ".join(tokens)+" "

# %%
# full_text = ' '.join(dict.fromkeys(full_text.split()))

# %%
wordcloud = WordCloud(collocations=False, width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(full_text)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
